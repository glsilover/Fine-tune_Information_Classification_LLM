# %% [markdown]
# # Part 1 : 数据爬取
# <br>

# %% [markdown]
# ### 任务目标
# 1. 利用feedparser库爬取RSS类信息流；
# 2. 利用BeautifulSoup库爬取通用HTML网页元素；
# 3. 利用selenium模拟真实用户行为爬取特殊的网页内容；
# 4. 将爬取的内容插入金山云RDS。
#
# <br>
# <br>

# %%
# !pip install PyYAML mysql-connector-python lxml python-dateutil requests selenium beautifulsoup4 feedparser webdriver-manager
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: PyYAML in /usr/lib/python3/dist-packages (5.4.1)
# Requirement already satisfied: mysql-connector-python in /home/ubuntu/.local/lib/python3.10/site-packages (9.1.0)
# Collecting lxml
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/05/9e/87492d03ff604fbf656ed2bf3e2e8d28f5d58ea1f00ff27ac27b06509079/lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 43.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil in /home/ubuntu/.local/lib/python3.10/site-packages (2.9.0.post0)
# Requirement already satisfied: requests in /home/ubuntu/.local/lib/python3.10/site-packages (2.32.3)
# Collecting selenium
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a6/1e/5f1a5dd2a28528c4b3ec6e076b58e4c035810c805328f9936123283ca14e/selenium-4.27.1-py3-none-any.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 38.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: beautifulsoup4 in /home/ubuntu/.local/lib/python3.10/site-packages (4.12.3)
# Collecting feedparser
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/7c/d4/8c31aad9cc18f451c49f7f9cfb5799dadffc88177f7917bc90a66459b1d7/feedparser-6.0.11-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 KB 28.0 MB/s eta 0:00:00
# Collecting webdriver-manager
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/b5/b5/3bd0b038d80950ec13e6a2c8d03ed8354867dc60064b172f2f4ffac8afbe/webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests) (1.26.5)
# Collecting trio~=0.17
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/3c/83/ec3196c360afffbc5b342ead48d1eb7393dd74fa70bca75d33905a86f211/trio-0.27.0-py3-none-any.whl (481 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.7/481.7 KB 20.3 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/12/90/3c9ff0512038035f59d279fddeb79f5f1eccd8859f06d6163c58798b9487/certifi-2024.8.30-py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.3/167.3 KB 57.1 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: websocket-client~=1.8 in /home/ubuntu/.local/lib/python3.10/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: typing_extensions~=4.9 in /home/ubuntu/.local/lib/python3.10/site-packages (from selenium) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from beautifulsoup4) (2.6)
# Collecting sgmllib3k
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9e/bd/3704a8c3e0942d711c1299ebf7b9091930adae6675d7c8f476a7ce48653c/sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging in /home/ubuntu/.local/lib/python3.10/site-packages (from webdriver-manager) (24.2)
# Collecting python-dotenv
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/6a/3e/b68c118422ec867fa7ab88444e1274aa40681c606d59ac27de5a5588f082/python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: exceptiongroup in /home/ubuntu/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.2.2)
# Requirement already satisfied: attrs>=23.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (24.2.0)
# Collecting sortedcontainers
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/32/46/9cb0e58b2deb7f82b84065f37f3bffeb12413f947f9388e4cac22c4621ce/sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting outcome
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/55/8b/5ab7257531a5d830fc8000c476e63c935488d74609b50f9384a643ec0a62/outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.1)
# Collecting wsproto>=0.14
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/78/58/e860788190eba3bcce367f74d29c4675466ce8dddfba85f7827588416f01/wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting PySocks!=1.5.7,<2.0,>=1.5.6
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/8d/59/b4572118e098ac8e46e399a1dd0f2d85403ce8bbaad9ec79373ed6badaf9/PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: h11<1,>=0.9.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=72af6870d27d111d6e064abbc3ce91fc4ab76fdf700bd581676fedede9a797d7
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/50/20/4b/e95fc891917d652cb6ecbfea035cf3ce640259cf857aaa21a7
# Successfully built sgmllib3k
# Installing collected packages: sortedcontainers, sgmllib3k, wsproto, python-dotenv, PySocks, outcome, lxml, feedparser, certifi, trio, webdriver-manager, trio-websocket, selenium
#   WARNING: The script dotenv is installed in '/home/ubuntu/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed PySocks-1.7.1 certifi-2024.8.30 feedparser-6.0.11 lxml-5.3.0 outcome-1.3.0.post0 python-dotenv-1.0.1 selenium-4.27.1 sgmllib3k-1.0.0 sortedcontainers-2.4.0 trio-0.27.0 trio-websocket-0.11.1 webdriver-manager-4.0.2 wsproto-1.2.0

# %%
import yaml
from IPython.display import display
import mysql.connector
import json
import feedparser
from bs4 import BeautifulSoup
from dateutil.tz import gettz
from datetime import datetime, timezone, timedelta
import pandas as pd
import requests

# %% [markdown]
# ---
# <br>
#
# ## 一、环境准备

# %%
with open(f'config_new.yaml', 'r') as file:
    config = yaml.safe_load(file)

# %%
# 定义时间转换函数

china_timezone = timezone(timedelta(hours=8))
def china_time_converter(*args):
    """
    自定义时间转换器，将UTC时间转换为北京时间。
    """
    utc_dt = datetime.utcnow().replace(tzinfo=timezone.utc)
    return utc_dt.astimezone(china_timezone).timetuple()

def convert_to_cst(datetime_str):
    # 解析日期字符串
    try:
        return parser.parse(datetime_str).astimezone(gettz("Asia/Shanghai"))
    except Exception as e:
        return datetime.now()

# %%
rss_source_list = []
web_source_list = []

rss_source_list = [config[source] for source in config['Source_List'] if config[source]['type'] == 'rss']
web_source_list = [config[source] for source in config['Source_List'] if config[source]['type'] != 'rss']

# %%
display(pd.DataFrame(rss_source_list))
display(pd.DataFrame(web_source_list))
# Out:
#                                                  url type               folder
# 0  https://aws.amazon.com/cn/blogs/machine-learni...  rss  AWS-MachineLearning
# 1                      https://research.fb.com/feed/  rss        Meta-Research
# 2               https://deepmind.google/blog/rss.xml  rss      DeepMind-Google
# 3            https://blogs.microsoft.com/ai/feed/rss  rss       Microsoft_Blog
# 4                         https://www.infoq.cn/feed/  rss                InfoQ
# 5                  https://www.36kr.com/feed-article  rss                 36kr
# 6                             https://sspai.com/feed  rss                sspai
#                                       url type           folder  \
# 0       https://openai.com/news/?limit=10  web      OpenAI_News
# 1  https://www.deeplearning.ai/the-batch/  web  deeplearning_ai
#
#                         domain
# 0           https://openai.com
# 1  https://www.deeplearning.ai

# %% [markdown]
# ---
# <br>
#
# ## 二、内容爬取
#
# ### 2.1 通过feedparser获取RSS源数据
#
# feedparser 是一个用来解析 RSS 和 Atom feeds 的 Python 库，用于从网络抓取和处理内容聚合数据，例如新闻、博客文章、播客等。只能解析标准化的 RSS 或 Atom feed 数据。能快速提取 feed 标题、条目标题、链接、摘要等。
# ![feedparser信息流展示](pictures/feedparser信息流展示.png)

# %%
def get_rss_article(source_content):
    content_list = []
    feed = feedparser.parse(source_content.get('url'))
    print(f"解析成功: {source_content.get('url')}, 共找到{len(feed.entries)}篇文章。\n")
    for entry in feed.entries:
        try:
            content_dict = {
                'title': entry.get('title', '无标题'),
                'link': entry.get('link', '未知链接'),
                'description_original': BeautifulSoup(entry.get('summary', '无描述'), "lxml").get_text(),  #由于summary并非纯文本格式，需要使用bs来去除HTML标签
                'source': source_content.get('folder'),
                'published_at': convert_to_cst(entry.get('published', '未知时间')),
                'folder': source_content.get('folder')
            }
            content_list.append(content_dict)
        except Exception as e:
            print(e)
            continue
    print('本次解析任务完成\n---')
    return content_list

# %%
content_list = get_rss_article(rss_source_list[0])
# Out:
# 解析成功: https://aws.amazon.com/cn/blogs/machine-learning/feed/, 共找到20篇文章。
#
# 本次解析任务完成
# ---

# %%
display(pd.DataFrame(content_list))
# Out:
#                                                 title  \
# 0   How Amazon trains sequential ensemble models a...
# 1   Implementing login node load balancing in Sage...
# 2   How Clearwater Analytics is revolutionizing in...
# 3   How Twitch used agentic workflow with RAG on A...
# 4   Accelerate analysis and discovery of cancer bi...
# 5   Accelerate your ML lifecycle using the new and...
# 6   Accelerate your ML lifecycle using the new and...
# 7   Amazon Q Apps supports customization and gover...
# 8   Answer questions from tables embedded in docum...
# 9   How AWS sales uses Amazon Q Business for custo...
# 10  Discover insights from your Amazon Aurora Post...
# 11  How Tealium built a chatbot evaluation platfor...
# 12  EBSCOlearning scales assessment generation for...
# 13  Pixtral 12B is now available on Amazon SageMak...
# 14  Talk to your slide deck using multimodal found...
# 15  Automate actions across enterprise application...
# 16  Accelerating ML experimentation with enhanced ...
# 17  Mistral-NeMo-Instruct-2407 and Mistral-NeMo-Ba...
# 18  Advancing AI trust with new responsible AI too...
# 19  Deploy RAG applications on Amazon SageMaker Ju...
#
#                                                  link  \
# 0   https://aws.amazon.com/blogs/machine-learning/...
# 1   https://aws.amazon.com/blogs/machine-learning/...
# 2   https://aws.amazon.com/blogs/machine-learning/...
# 3   https://aws.amazon.com/blogs/machine-learning/...
# 4   https://aws.amazon.com/blogs/machine-learning/...
# 5   https://aws.amazon.com/blogs/machine-learning/...
# 6   https://aws.amazon.com/blogs/machine-learning/...
# 7   https://aws.amazon.com/blogs/machine-learning/...
# 8   https://aws.amazon.com/blogs/machine-learning/...
# 9   https://aws.amazon.com/blogs/machine-learning/...
# 10  https://aws.amazon.com/blogs/machine-learning/...
# 11  https://aws.amazon.com/blogs/machine-learning/...
# 12  https://aws.amazon.com/blogs/machine-learning/...
# 13  https://aws.amazon.com/blogs/machine-learning/...
# 14  https://aws.amazon.com/blogs/machine-learning/...
# 15  https://aws.amazon.com/blogs/machine-learning/...
# 16  https://aws.amazon.com/blogs/machine-learning/...
# 17  https://aws.amazon.com/blogs/machine-learning/...
# 18  https://aws.amazon.com/blogs/machine-learning/...
# 19  https://aws.amazon.com/blogs/machine-learning/...
#
#                                  description_original               source  \
# 0   Ensemble models are becoming popular within th...  AWS-MachineLearning
# 1   In this post, we explore a solution for implem...  AWS-MachineLearning
# 2   In this post, we explore Clearwater Analytics’...  AWS-MachineLearning
# 3   In this post, we demonstrate how we innovated ...  AWS-MachineLearning
# 4   Bedrock multi-agent collaboration enables deve...  AWS-MachineLearning
# 5   In Part 1 of this series, we introduced the ne...  AWS-MachineLearning
# 6   In this post, we focus on the ModelTrainer cla...  AWS-MachineLearning
# 7   In this post, we examine how these features en...  AWS-MachineLearning
# 8   Amazon Q Business launched support for tabular...  AWS-MachineLearning
# 9   In April 2024, we launched our AI sales assist...  AWS-MachineLearning
# 10  In this post, we walk you through configuring ...  AWS-MachineLearning
# 11  In this post, we illustrate the importance of ...  AWS-MachineLearning
# 12  In this post, we illustrate how EBSCOlearning ...  AWS-MachineLearning
# 13  Today, we are excited to announce that Pixtral...  AWS-MachineLearning
# 14  In Parts 1 and 2 of this series, we explored w...  AWS-MachineLearning
# 15  Amazon Q Business is a generative AI-powered a...  AWS-MachineLearning
# 16  With access to a wide range of generative AI f...  AWS-MachineLearning
# 17  Today, we are excited to announce that Mistral...  AWS-MachineLearning
# 18  With trust as a cornerstone of AI adoption, we...  AWS-MachineLearning
# 19  In this post, we show how to build a RAG appli...  AWS-MachineLearning
#
#                  published_at               folder
# 0  2024-12-16 17:28:15.600928  AWS-MachineLearning
# 1  2024-12-16 17:28:15.601269  AWS-MachineLearning
# 2  2024-12-16 17:28:15.601499  AWS-MachineLearning
# 3  2024-12-16 17:28:15.601714  AWS-MachineLearning
# 4  2024-12-16 17:28:15.601947  AWS-MachineLearning
# 5  2024-12-16 17:28:15.602453  AWS-MachineLearning
# 6  2024-12-16 17:28:15.602668  AWS-MachineLearning
# 7  2024-12-16 17:28:15.602885  AWS-MachineLearning
# 8  2024-12-16 17:28:15.603091  AWS-MachineLearning
# 9  2024-12-16 17:28:15.603291  AWS-MachineLearning
# 10 2024-12-16 17:28:15.603484  AWS-MachineLearning
# 11 2024-12-16 17:28:15.603692  AWS-MachineLearning
# 12 2024-12-16 17:28:15.603903  AWS-MachineLearning
# 13 2024-12-16 17:28:15.604105  AWS-MachineLearning
# 14 2024-12-16 17:28:15.604306  AWS-MachineLearning
# 15 2024-12-16 17:28:15.604508  AWS-MachineLearning
# 16 2024-12-16 17:28:15.604717  AWS-MachineLearning
# 17 2024-12-16 17:28:15.604934  AWS-MachineLearning
# 18 2024-12-16 17:28:15.605136  AWS-MachineLearning
# 19 2024-12-16 17:28:15.605365  AWS-MachineLearning

# %% [markdown]
# <br>
#
# ### 2.2 通过BeautifulSoup爬取deeplearning_ai内容
# 用于解析和处理 HTML/XML 的 Python 库，常与 lxml 或 html.parser 等解析器一起使用。它提供了一套简洁的 API，方便开发者从网页或 XML 数据中提取结构化信息。能解析任何 HTML/XML 内容，不依赖于特定格式（如 RSS/Atom）。可以处理不完整或格式不规范的 HTML。
#
# ![bs4爬取网页内容](pictures/bs4爬取网页内容.png)

# %%
def deeplearning_ai(source_content):
    content_list = []
    # 获取网页内容并解析文章
    notice_items = BeautifulSoup(requests.get(source_content.get('url')).text, 'lxml').find_all('article')
    for item in notice_items:
        target_link = ''
        try:
            # 提取文章链接
            target_link = next((source_content.get('domain') + link.get('href') for link in item.find_all('a') if 'issue' in link.get('href')), '')
            # 提取发布时间和简介
            divs = item.find_all('div')
            published_at = divs[1].find_all('div')[0].text if len(divs) >= 2 else ''
            description_original = divs[1].find_all('div')[1].text if len(divs) >= 2 else ''
            # 构建文章字典
            content_dict = {
                'title': BeautifulSoup(item.find('h2').text.strip(), "lxml").get_text(),
                'link': target_link,
                'description_original': BeautifulSoup(description_original, "lxml").get_text(),
                'source': source_content.get('folder'),
                'published_at': convert_to_cst(BeautifulSoup(published_at, "lxml").get_text()),
                'folder': source_content.get('folder')
            }
            content_list.append(content_dict)

        except Exception as e:
            continue
    return content_list

# %%
content_web_list = deeplearning_ai(web_source_list[1])
display(pd.DataFrame(content_web_list))
# Out:
# /tmp/ipykernel_496330/4074190371.py:16: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   'title': BeautifulSoup(item.find('h2').text.strip(), "lxml").get_text(),
#                                                 title  \
# 0   Amazon Nova’s Competitive Price/Performance, O...
# 1   AI Agents Spend Real Money, Breaking Jailbreak...
# 2   DeepSeek Takes On OpenAI, Robots Fold Laundry,...
# 3   Next-Gen Models Show Limited Gains, Real-Time ...
# 4   Llama On the Battlefield, Mixture of Experts P...
# 5   AI Controls Desktops, Agents Train Algorithms,...
# 6   Trick or treat! AI Devours Energy, Innovation ...
# 7   AI Giants Go Nuclear, A Tech Bromance Turns Tu...
# 8   Bogus Apps, AI Boomtown, Better Embeddings, 20...
# 9   How Meta’s Movie Gen Does It, AI’s Criminal Un...
# 10  Llama Goes Multimodal, Pros Embrace Generative...
# 11  Hollywood Embraces Video Gen, New Restrictions...
# 12  Models Built for Reasoning, High Gear for Llam...
# 13  Nations Sign Binding AI Treaty, Waymo Reveals ...
# 14  Hallucination Index, AI-Powered Policing Goes ...
# 15  AI Restores ALS Patient’s Voice, AI Lobby Grow...
#
#                                                 link  \
# 0   https://www.deeplearning.ai/the-batch/issue-279/
# 1   https://www.deeplearning.ai/the-batch/issue-278/
# 2   https://www.deeplearning.ai/the-batch/issue-277/
# 3   https://www.deeplearning.ai/the-batch/issue-276/
# 4   https://www.deeplearning.ai/the-batch/issue-275/
# 5   https://www.deeplearning.ai/the-batch/issue-274/
# 6   https://www.deeplearning.ai/the-batch/issue-273/
# 7   https://www.deeplearning.ai/the-batch/issue-272/
# 8   https://www.deeplearning.ai/the-batch/issue-271/
# 9   https://www.deeplearning.ai/the-batch/issue-270/
# 10  https://www.deeplearning.ai/the-batch/issue-269/
# 11  https://www.deeplearning.ai/the-batch/issue-268/
# 12  https://www.deeplearning.ai/the-batch/issue-267/
# 13  https://www.deeplearning.ai/the-batch/issue-266/
# 14  https://www.deeplearning.ai/the-batch/issue-265/
# 15  https://www.deeplearning.ai/the-batch/issue-264/
#
#                                  description_original           source  \
# 0   The Batch AI News and Insights: AI Product Man...  deeplearning_ai
# 1   The Batch AI News and Insights: AI Agents Spen...  deeplearning_ai
# 2   The Batch AI News and Insights: DeepSeek Takes...  deeplearning_ai
# 3   The Batch AI News and Insights: A small number...  deeplearning_ai
# 4   The Batch AI News and Insights: Large language...  deeplearning_ai
# 5   The Batch AI News and Insights: Trump and the ...  deeplearning_ai
# 6   The Batch AI News and Insights: Welcome to our...  deeplearning_ai
# 7   The Batch AI News and Insights: Startups live ...  deeplearning_ai
# 8   The Batch AI News and Insights: It’s high time...  deeplearning_ai
# 9   The Batch AI News and Insights: Congratulation...  deeplearning_ai
# 10  The Batch AI News and Insights: We won! Califo...  deeplearning_ai
# 11  The Batch AI News and Insights: Last week I sp...  deeplearning_ai
# 12  The Batch AI News and Insights: Years ago, whe...  deeplearning_ai
# 13  The Batch AI News and Insights: Over the weeke...  deeplearning_ai
# 14  The Batch AI News and Insights: Recently I vis...  deeplearning_ai
# 15  The Batch AI News and Insights: After a recent...  deeplearning_ai
#
#                  published_at           folder
# 0  2024-12-16 17:28:52.332433  deeplearning_ai
# 1  2024-12-16 17:28:52.333385  deeplearning_ai
# 2  2024-12-16 17:28:52.334141  deeplearning_ai
# 3  2024-12-16 17:28:52.335033  deeplearning_ai
# 4  2024-12-16 17:28:52.335767  deeplearning_ai
# 5  2024-12-16 17:28:52.336489  deeplearning_ai
# 6  2024-12-16 17:28:52.337211  deeplearning_ai
# 7  2024-12-16 17:28:52.337967  deeplearning_ai
# 8  2024-12-16 17:28:52.338707  deeplearning_ai
# 9  2024-12-16 17:28:52.339621  deeplearning_ai
# 10 2024-12-16 17:28:52.340342  deeplearning_ai
# 11 2024-12-16 17:28:52.341054  deeplearning_ai
# 12 2024-12-16 17:28:52.341764  deeplearning_ai
# 13 2024-12-16 17:28:52.342472  deeplearning_ai
# 14 2024-12-16 17:28:52.343192  deeplearning_ai
# 15 2024-12-16 17:28:52.344081  deeplearning_ai

# %% [markdown]
# <br>
#
# ### 2.3 通过selenium模拟浏览器爬取OpenAI News
# 可以模拟用户操作浏览器的行为，它适用于网页测试、爬虫开发、表单提交和动态内容抓取等场景。无需打开实际浏览器窗口（Headless Mode），更适合后台运行任务。模拟点击、输入、拖拽、滚动等用户行为，支持执行自定义的 JavaScript 脚本。

# %%
# import lxml
# import time
# from selenium import webdriver
# from selenium.webdriver.chrome.options import Options
# from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# %%
def OpenAI_News(self):
    # 设置Chrome浏览器选项
    chrome_options = Options()
    chrome_options.add_argument('--disable-gpu')
    chrome_options.add_argument('--no-sandbox')

    # 设置无头模式
    chrome_options.add_argument('--headless')
    chrome_options.add_argument('--disable-dev-shm-usage')

    # 隐藏自动化特征
    chrome_options.add_argument('--disable-blink-features=AutomationControlled')
    chrome_options.add_experimental_option('excludeSwitches', ['enable-automation'])
    chrome_options.add_experimental_option('useAutomationExtension', False)
    chrome_options.add_argument("--disable-web-security")  # 允许跨域
    chrome_options.add_argument("--allow-running-insecure-content")
    chrome_options.add_argument("--disable-site-isolation-trials")

    # 修改 User-Agent
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
    chrome_options.add_argument(f'user-agent={user_agent}')

    # 初始化浏览器
    prefs = {
        "profile.managed_default_content_settings.images": 2,
        "profile.default_content_setting_values.notifications": 2,
        "profile.default_content_setting_values.stylesheets": 2,
        "profile.default_content_setting_values.cookies": 2,
        "profile.default_content_setting_values.javascript": 1,
        "profile.default_content_setting_values.plugins": 2,
        "profile.default_content_setting_values.popups": 2,
        "profile.default_content_setting_values.geolocation": 2,
        "profile.default_content_setting_values.media_stream": 2,
    }
    chrome_options.add_experimental_option("prefs", prefs)

    # 初始化浏览器
    service = Service(ChromeDriverManager().install(), log_path='/dev/null')
    driver = webdriver.Chrome(service=service, options=chrome_options)
    # 打开网页
    driver.get(self.source_url)
    # 等待页面加载完成（根据需要调整时间）
    time.sleep(30)
    # 获取渲染后的页面源代码
    html_content = driver.page_source
    # 关闭浏览器
    driver.quit()

    # 解析HTML内容
    soup = BeautifulSoup(html_content, 'lxml')

    # 查找符合条件的<div>
    notice_items = soup.select('div.col-span-1.transition.opacity-1.ease-curve-c.duration-400')
    for item in notice_items:
        try:
            # 获取link
            other_content = item.find_all('span')
            content = item.find('a')
            try:
                published_at = other_content[1].text
            except Exception as e:
                logging.error(f"文章“published_at”字段解析失败:{e}，文章内容为\n{item}")
                published_at = ''
            try:
                description_original = other_content[0].text
            except Exception as e:
                logging.info(f"文章“description_original”字段解析失败:{e}，文章内容为\n{item}")
                description_original = ''
            if content:
                content_dict = {
                    'title': BeautifulSoup(content.get('aria-label'), "lxml").get_text(),
                    'link': self.domain + content.get('href'),
                    'description_original': BeautifulSoup(description_original, "lxml").get_text(),
                    'source': self.source,
                    'published_at': convert_to_cst(BeautifulSoup(published_at, "lxml").get_text()),
                    'folder': self.folder
                }
                self.article_data_list.append(content_dict)
            else:
                logging.info("未找到元素")

        except Exception as e:
            logging.error(f"解析文章失败:{item} {e}，文章内容为\n{item}")
            continue
    return self.article_data_list

# %% [markdown]
# ---
# <br>
#
# ## 三、数据库插入

# %%
mysql_message = config['mysql']
connection = mysql.connector.connect(
        host=mysql_message['host'],
        port=mysql_message['port'],
        database=mysql_message['database'],
        user=mysql_message['user'],
        password=mysql_message['password'],
        ssl_disabled=True
    )

# %%
if connection is not None:
    cursor = connection.cursor()
    for content in content_list:
        try:
            # 检查是否存在相同title的文章
            check_query = "SELECT 1 FROM original_article_table WHERE title = %s"
            cursor.execute(check_query, (content['title'],))
            if cursor.fetchone():
                # 如果找到了，说明已存在相同title的文章，跳过插入
                print(f"【Skipping】 Article '{content['title']}' already exists, skipping.")
                continue

            # 构造SQL插入语句，包括所有字段
            insert_query = """
                        INSERT INTO original_article_table (title, link, description_original, source, published_at, is_processed, folder) 
                        VALUES (%s, %s, %s, %s, %s, %s, %s)
                        ON DUPLICATE KEY UPDATE title=VALUES(title)
                        """
            # 从article_content字典中提取字段值
            title = content['title']
            link = content['link']
            description_original = content['description_original']
            folder = content['folder']
            source = content['source']  # 假设source字段从类属性获取或其他逻辑
            published_at = content['published_at']  # 确保published_at是datetime对象
            is_processed = False

            # 执行SQL语句
            cursor.execute(insert_query, (title, link, description_original, source, published_at, is_processed, folder))
            connection.commit()
            print(f"【successfully】 Article '{title}' inserted successfully.")
        except mysql.connector.Error as e:
            print(f"【Failed】 Failed to insert article '{content['title']}'. MySQL Error: {e}")
            continue  # 即使发生错误也继续尝试插入下一篇文章
    cursor.close()
# Out:
# 【Skipping】 Article 'How Amazon trains sequential ensemble models at scale with Amazon SageMaker Pipelines' already exists, skipping.
# 【Skipping】 Article 'Implementing login node load balancing in SageMaker HyperPod for enhanced multi-user experience' already exists, skipping.
# 【Skipping】 Article 'How Clearwater Analytics is revolutionizing investment management with generative AI and Amazon SageMaker JumpStart' already exists, skipping.
# 【Skipping】 Article 'How Twitch used agentic workflow with RAG on Amazon Bedrock to supercharge ad sales' already exists, skipping.
# 【Skipping】 Article 'Accelerate analysis and discovery of cancer biomarkers with Amazon Bedrock Agents' already exists, skipping.
# 【Skipping】 Article 'Accelerate your ML lifecycle using the new and improved Amazon SageMaker Python SDK – Part 2: ModelBuilder' already exists, skipping.
# 【Skipping】 Article 'Accelerate your ML lifecycle using the new and improved Amazon SageMaker Python SDK – Part 1: ModelTrainer' already exists, skipping.
# 【Skipping】 Article 'Amazon Q Apps supports customization and governance of generative AI-powered apps' already exists, skipping.
# 【Skipping】 Article 'Answer questions from tables embedded in documents with Amazon Q Business' already exists, skipping.
# 【Skipping】 Article 'How AWS sales uses Amazon Q Business for customer engagement' already exists, skipping.
# 【Skipping】 Article 'Discover insights from your Amazon Aurora PostgreSQL database using the Amazon Q Business connector' already exists, skipping.
# 【Skipping】 Article 'How Tealium built a chatbot evaluation platform with Ragas and Auto-Instruct using AWS generative AI services' already exists, skipping.
# 【Skipping】 Article 'EBSCOlearning scales assessment generation for their online learning content with generative AI' already exists, skipping.
# 【Skipping】 Article 'Pixtral 12B is now available on Amazon SageMaker JumpStart' already exists, skipping.
# 【Skipping】 Article 'Talk to your slide deck using multimodal foundation models on Amazon Bedrock – Part 3' already exists, skipping.
# 【Skipping】 Article 'Automate actions across enterprise applications using Amazon Q Business plugins' already exists, skipping.
# 【Skipping】 Article 'Accelerating ML experimentation with enhanced security: AWS PrivateLink support for Amazon SageMaker with MLflow' already exists, skipping.
# 【Skipping】 Article 'Mistral-NeMo-Instruct-2407 and Mistral-NeMo-Base-2407 are now available on SageMaker JumpStart' already exists, skipping.
# 【Skipping】 Article 'Advancing AI trust with new responsible AI tools, capabilities, and resources' already exists, skipping.
# 【Skipping】 Article 'Deploy RAG applications on Amazon SageMaker JumpStart using FAISS' already exists, skipping.

# %%
connection.close()
